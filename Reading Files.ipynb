# %% [markdown]
# # Diffrent Kind of Files

# %% [markdown]
# * Microsoft XLSX
# * Comma Seperated Values_(csv) (delimited file)
# * JavaScript Object Notation_(JSON) (Open standard file format)
# * Hadoop Distributed File System_(HDFS)
# * Statistical Analysis System_(SAS)
# * Statistical Package for Social Sciences_(SPSS)

# %% [markdown]
# # Flat Files: CSV
# * Store data in plain text
# * No Structures replationship

# %%
import pandas as pd

# %%
iris = pd.read_csv(r'C:\Users\user\Desktop\Git_Python\New folder\data\Iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.shape
# Out:
# (150, 6)

# %% [markdown]
# # Reading Tab seperated file

# %%
#Tab seperated file is as delimiter file
# in a pd.read_csv(r'  ',sep = '\t')amazon data file missing

# %% [markdown]
# # Reading XLSX

# %% [markdown]
# * excel = pd.read_excel(r'filename.xls')

# %% [markdown]
# # Reading JASON file
# * pd.read_json(r'filename.json')

# %% [markdown]
# # R eading HTML from WIKIPEDIA
# * HyperTextMarkup lanhuage
# * Standard markup language for doucuments
# * Format structure of webpage

# %%
# 2021 List of states in India by past population
url = "https://en.wikipedia.org/wiki/List_of_states_in_India_by_past_population"
tabels = pd.read_html(url)

# %%
tabels
# Out:
# [     Rank     State or union territory  Population (1951 Census)[11]  \
#  0       1                Uttar Pradesh                    60274800.0
#  1       2                  Maharashtra                    32002500.0
#  2       3                        Bihar                    29085900.0
#  3       4                  West Bengal                    26300670.0
#  4       5               Madhya Pradesh                    18615700.0
#  5       6                   Tamil Nadu                    30119680.0
#  6       7                    Rajasthan                    15971130.0
#  7       8                    Karnataka                    19402500.0
#  8       9                      Gujarat                    16263700.0
#  9      10               Andhra Pradesh                    31115000.0
#  10     11                       Odisha                    14646100.0
#  11     12                    Telangana                           NaN
# ...

# %%
# To check how many tabels we read
len(tabels)
# Out:
# 2

# %%
# How to check the tabels inside the page by using "indexes"
tabels[0]
# Out:
#      Rank     State or union territory  Population (1951 Census)[11]  \
# 0       1                Uttar Pradesh                    60274800.0
# 1       2                  Maharashtra                    32002500.0
# 2       3                        Bihar                    29085900.0
# 3       4                  West Bengal                    26300670.0
# 4       5               Madhya Pradesh                    18615700.0
# 5       6                   Tamil Nadu                    30119680.0
# 6       7                    Rajasthan                    15971130.0
# 7       8                    Karnataka                    19402500.0
# 8       9                      Gujarat                    16263700.0
# 9      10               Andhra Pradesh                    31115000.0
# 10     11                       Odisha                    14646100.0
# 11     12                    Telangana                           NaN
# 12     13                       Kerala                    13549000.0
# ...

# %%
tabels[1]
# Out:
#     States and union territories of India ordered by
# 0  Area Population GDP (per capita) Abbreviations...
# 1  .mw-parser-output .navbar{display:inline;font-...

# %% [markdown]
# # Reading MYSQL data

# %%
# !pip install mysql

# %%
import mysql.connector as sql

# %% [markdown]
# # creating connection
# db = sql.connect(host = 'localhost' , user = 'root' , passwd = 'amjad@143', database = 'amjad' ,
#                  auth_plugin = 'mysql_native_password')

# %% [markdown]
# queery = "select * from employee"
# data = pd.read_sql(query.db)

# %% [markdown]
# ## SAS(statistical analysis system)
# df = pd.read_sas('filename.sas7bdat')

# %% [markdown]
# # To read SPSS
# * Statical package for social sciences

# %%
# !pip install pyreadstat

# %%
import pyreadstat

# %% [markdown]
# df , meta = pyreadstat.read_sas7bdt(filename.sas7bdat)

# %% [markdown]
# * Toread :
# pandas.read_spss

# %% [markdown]
# df pd.read_spss('filename.sav')
