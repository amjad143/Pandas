# %% [markdown]
# ### Selecting multiple DataFrame columns
# #### Selecting columns with methods
# #### Ordering column names sensibly
# ##### Operating on the entire DataFrame
# ##### Chaining DataFrame method together

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\user\Desktop\Git_Python\New folder\data\movie.csv',index_col='movie_title')
df.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %% [markdown]
# # Selecting Multiple DataFrame

# %%
# Showing all the columns
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
#Displaying selected particular column name
movie_actor_director = df[['actor_1_name','actor_2_name','actor_3_name','director_name']]

# %%
movie_actor_director.head()
# Out:
#                                                actor_1_name      actor_2_name  \
# movie_title
# Avatar                                          CCH Pounder  Joel David Moore
# Pirates of the Caribbean: At World's End        Johnny Depp     Orlando Bloom
# Spectre                                     Christoph Waltz      Rory Kinnear
# The Dark Knight Rises                             Tom Hardy    Christian Bale
# Star Wars: Episode VII - The Force Awakens      Doug Walker        Rob Walker
#
#                                                     actor_3_name  \
# movie_title
# Avatar                                                 Wes Studi
# Pirates of the Caribbean: At World's End          Jack Davenport
# Spectre                                         Stephanie Sigman
# The Dark Knight Rises                       Joseph Gordon-Levitt
# Star Wars: Episode VII - The Force Awakens                   NaN
#
#                                                 director_name
# movie_title
# ...

# %%
#selecting a single column as a DataFrame
df[['director_name']].head()
# Out:
#                                                 director_name
# movie_title
# Avatar                                          James Cameron
# Pirates of the Caribbean: At World's End       Gore Verbinski
# Spectre                                            Sam Mendes
# The Dark Knight Rises                       Christopher Nolan
# Star Wars: Episode VII - The Force Awakens        Doug Walker

# %% [markdown]
# ## Selecting columns with methods
# ### Using methods like get_dtype_counts,select_dtypes,filter

# %%
#by using get_dtype we get the each specified data
df.dtypes.value_counts()
# Out:
# float64    13
# object     11
# int64       3
# dtype: int64

# %%
#Selecting only integer column
df.select_dtypes(include=['integer']).head()
# Out:
#                                             num_voted_users  \
# movie_title
# Avatar                                               886204
# Pirates of the Caribbean: At World's End             471220
# Spectre                                              275868
# The Dark Knight Rises                               1144337
# Star Wars: Episode VII - The Force Awakens                8
#
#                                             cast_total_facebook_likes  \
# movie_title
# Avatar                                                           4834
# Pirates of the Caribbean: At World's End                        48350
# Spectre                                                         11700
# The Dark Knight Rises                                          106759
# Star Wars: Episode VII - The Force Awakens                        143
#
#                                             movie_facebook_likes
# movie_title
# Avatar                                                     33000
# ...

# %%
# Selecting only Numeric column
df.select_dtypes(include=['number']).head()
# Out:
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
# ...

# %%
#Selecting Alternative Column ,here takes the string
df.filter(like='facebook').head()
# Out:
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                             actor_1_facebook_likes  \
# movie_title
# ...

# %%
#Selecting by numbers paramters display index :(\d :0-9)matches any string 
df.filter (regex='\d').head()
# Out:
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# ...

# %%
#Selecting exact column name
df.filter(items=['actor_1_name','asdf']).head()
# Out:
#                                                actor_1_name
# movie_title
# Avatar                                          CCH Pounder
# Pirates of the Caribbean: At World's End        Johnny Depp
# Spectre                                     Christoph Waltz
# The Dark Knight Rises                             Tom Hardy
# Star Wars: Episode VII - The Force Awakens      Doug Walker

# %% [markdown]
# # Ordering Column Names Sensibly
# ### Ordering columns by ProperGuidelines to columns
# #Guidelines to Order columns
# #Classify each column as either discete or continuous
# #Group commom columns with discrete and continuous columns
# #Place the most important group of columns first

# %%
df1=pd.read_csv(r'C:\Users\user\Desktop\Git_Python\New folder\data\movie.csv')
df1.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df1.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
# Arranging all the columns in a order either discreate or continues
disc_core = ['movie_title','title_year','content_rating','genres']
disc_people = ['director_name','actor_1_name','actor_2_name','actor_3_name']
disc_others =['color','country','language','plot_keywords','movie_imdb_link']
cont_fb = ['director_facebook_likes','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes',
           'cast_total_facebook_likes','movie_facebook_likes']
cont_finance = ['budget','gross']
cont_num_reviews = ['num_voted_users','num_user_for_reviews','num_critic_for_reviews']
cont_other = ['imdb_score','duration','aspect_ratio','facenumber_in_poster']

# %%
new_col_order = disc_core+disc_people+disc_others+cont_fb+\
                cont_finance+cont_num_reviews+cont_other

# %%
#here we get true we are checking entire data
set(df1.columns) == set(new_col_order)
# Out:
# True

# %%
#re- arrange all the columns in order way
df1[new_col_order].head()
# Out:
#                                   movie_title  title_year content_rating  \
# 0                                      Avatar      2009.0          PG-13
# 1    Pirates of the Caribbean: At World's End      2007.0          PG-13
# 2                                     Spectre      2015.0          PG-13
# 3                       The Dark Knight Rises      2012.0          PG-13
# 4  Star Wars: Episode VII - The Force Awakens         NaN            NaN
#
#                             genres      director_name     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      James Cameron      CCH Pounder
# 1         Action|Adventure|Fantasy     Gore Verbinski      Johnny Depp
# 2        Action|Adventure|Thriller         Sam Mendes  Christoph Waltz
# 3                  Action|Thriller  Christopher Nolan        Tom Hardy
# 4                      Documentary        Doug Walker      Doug Walker
#
#        actor_2_name          actor_3_name  color country  ...  \
# ...

# %% [markdown]
# # Operating on the Entire DataFrame
# #Exploring most common DataFrame attributes and methods

# %%
#To display no of rows and columns in a tuple
df1.shape
# Out:
# (4916, 28)

# %%
#To disply no of elements
df1.size
# Out:
# 137648

# %%
#To display number of dimensions in the data frame
df1.ndim
# Out:
# 2

# %%
#To display no rows
len(df1)
# Out:
# 4916

# %%
#T display no missing values to each columns
df1.count()
# Out:
# color                        4897
# director_name                4814
# num_critic_for_reviews       4867
# duration                     4901
# director_facebook_likes      4814
# actor_3_facebook_likes       4893
# actor_2_name                 4903
# actor_1_facebook_likes       4909
# gross                        4054
# genres                       4916
# actor_1_name                 4909
# movie_title                  4916
# num_voted_users              4916
# cast_total_facebook_likes    4916
# actor_3_name                 4893
# facenumber_in_poster         4903
# plot_keywords                4764
# movie_imdb_link              4916
# num_user_for_reviews         4895
# language                     4904
# country                      4911
# content_rating               4616
# budget                       4432
# title_year                   4810
# actor_2_facebook_likes       4903
# imdb_score                   4916
# aspect_ratio                 4590
# ...

# %%
#To display all the statistics
df1.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 25%                 49.000000    93.000000                 7.000000
# 50%                108.000000   103.000000                48.000000
# 75%                191.000000   118.000000               189.750000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
#To check the Quantiles nothing but percentage
df1.describe(percentiles=[.01,.3,.99])
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 1%                   2.000000    43.000000                 0.000000
# 30%                 60.000000    95.000000                11.000000
# 50%                108.000000   103.000000                48.000000
# 99%                546.680000   189.000000             16000.000000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# ...

# %% [markdown]
# # Changing DataFrame Method
# #counting all missing values in each column

# %%
df1.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
# To checking missing values
df.isnull().head()
#to show in the boolen values
# Out:
#                                             color  director_name  \
# movie_title
# Avatar                                      False          False
# Pirates of the Caribbean: At World's End    False          False
# Spectre                                     False          False
# The Dark Knight Rises                       False          False
# Star Wars: Episode VII - The Force Awakens   True          False
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       False     False
# Pirates of the Caribbean: At World's End                     False     False
# Spectre                                                      False     False
# The Dark Knight Rises                                        False     False
# Star Wars: Episode VII - The Force Awakens                    True      True
#
#                                             director_facebook_likes  \
# ...

# %%
#.dtypes.value_counts()  replace ".get_dtype_counts()"

# %%
# Checking the count of the data the are missing values
df.isnull().dtypes.value_counts()
# Out:
# bool    27
# dtype: int64

# %%
# TO check the series method
df.isnull().sum().head()
# Out:
# color                       19
# director_name              102
# num_critic_for_reviews      49
# duration                    15
# director_facebook_likes    102
# dtype: int64

# %%
# To check the total number of missing values on a sclar value
df.isnull().sum().sum()
#to check the grand total in the data frame
# Out:
# 2654

# %%
#To check the missing bollen values
df.isnull().any().any()
#if we are getting here True then it means having atleast one missing value in the data frame
# Out:
# True
