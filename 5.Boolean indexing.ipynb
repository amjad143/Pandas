# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Boolen Indexing
# * Cliculating boolean stat
# * Constructing multiple Boolean conditions
# * Filtering with Boolean inexing
# * Replicating Boolean indexing with index selection
# * Selecting rows with unique and sorted indexes
# * Gaining perspective on stock prices

# %% [markdown]
# ## Caliculating boolen statistics
# * Translating SQL WHERE clauses
# * Determining the normality of stock market returns
# * Improving DataFrame rows
# * Preserving series with where method
# * Masking DataFrame rows
# * Selecting with Booleans,integer location and labels

# %%
df = pd.read_csv(r'C:\Users\user\Desktop\Git_Python\New folder\data\movie.csv',index_col='movie_title')
df.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
# check the duration of the movie
#to produce boolen we apply to on of the column for the comparision
df_2 = df['duration']>120
df_2.head(10)
# Out:
# movie_title
# Avatar                                         True
# Pirates of the Caribbean: At World's End       True
# Spectre                                        True
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# John Carter                                    True
# Spider-Man 3                                   True
# Tangled                                       False
# Avengers: Age of Ultron                        True
# Harry Potter and the Half-Blood Prince         True
# Name: duration, dtype: bool

# %%
# to check all the data which are longer than 2 hours
df_2.sum()
# Out:
# 1039

# %%
# to check the percentage of the movie longer than 2 hours is "mean" method
df_2.mean()
# Out:
# 0.2113506916192026

# %% [markdown]
# * So there are 20% of the movies longer than 2 hours criteria

# %%
# to verify our self we use to get the distribution
df_2.value_counts(normalize=True)
# Out:
# False    0.788649
# True     0.211351
# Name: duration, dtype: float64

# %% [markdown]
# * before doing this check the missing data and replace the values

# %%
# lets do this and check the mean in single line by chaining method
df['duration'].dropna().gt(120).mean()
# Out:
# 0.21199755152009794

# %%
#After this we will find some boolen statistics
df_2.describe()
# Out:
# count      4916
# unique        2
# top       False
# freq       3877
# Name: duration, dtype: object

# %% [markdown]
# # Example problem
# Determine the percentage of movies:
# actor 1 has more facebook likes than actor 2,
# select both of these columns,
# make comparision,
# caliculate mean.

# %%
actor = df[['actor_1_facebook_likes','actor_2_facebook_likes']].dropna()
(actor['actor_1_facebook_likes']>actor['actor_2_facebook_likes']).mean()
# Out:
# 0.9777687130328371

# %% [markdown]
# # Constructing munltiple boolen conditions
# * Creating variable to hold each set of criteria independently
# * Combining all the criteria together into single Boolean Series

# %% [markdown]
# * (and,or,not do not work in boolen indexing in pandas)
# * (ther are replaced with "&","|","~" with wrapped in "()")

# %%
criteria1 = df.imdb_score > 8
criteria2 = df.content_rating =='PG-13'
criteria3 = (df.title_year<2000) | (df.title_year>=2010)

# %%
criteria2.head()
# Out:
# movie_title
# Avatar                                         True
# Pirates of the Caribbean: At World's End       True
# Spectre                                        True
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# Name: content_rating, dtype: bool

# %%
criteria_final1 = criteria1 & criteria2 & criteria3
criteria_final1.head()
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# dtype: bool

# %% [markdown]
# # Filtering with boolen indexing
# * Creating two sets of movies with diffrent criteria
# * Combining the two sets using the or operator
# * Passing it to the indexing operator to filter data

# %%
criteria_final1 = criteria1 & criteria2 & criteria3

# %%
criteria_a1 = df.imdb_score < 5
criteria_a2 = df.content_rating =='R'
criteria_a3 = (df.title_year >= 2000) | (df.title_year <=2010)
criteria_final2 = criteria_a1 & criteria_a2 & criteria_a3

# %%
#combining two criterias with or operator
criteria_final_all = criteria_final1 | criteria_final2
criteria_final_all.head()
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# dtype: bool

# %%
# simply pass it to the indexing opertor to filter the data
df[criteria_final_all].head()
# Out:
#                             color      director_name  num_critic_for_reviews  \
# movie_title
# The Dark Knight Rises       Color  Christopher Nolan                   813.0
# The Avengers                Color        Joss Whedon                   703.0
# Captain America: Civil War  Color      Anthony Russo                   516.0
# The Lovers                  Color       Roland Joffé                    10.0
# Guardians of the Galaxy     Color         James Gunn                   653.0
#
#                             duration  director_facebook_likes  \
# movie_title
# The Dark Knight Rises          164.0                  22000.0
# The Avengers                   173.0                      0.0
# Captain America: Civil War     147.0                     94.0
# The Lovers                     109.0                    596.0
# Guardians of the Galaxy        121.0                    571.0
#
#                             actor_3_facebook_likes        actor_2_name  \
# movie_title
# ...

# %%
#to verify check the rows and columns with "loc" index
col = ['imdb_score','content_rating','title_year']
df_filter = df.loc[criteria_final_all,col]
df_filter.head(10)
# Out:
#                             imdb_score content_rating  title_year
# movie_title
# The Dark Knight Rises              8.5          PG-13      2012.0
# The Avengers                       8.1          PG-13      2012.0
# Captain America: Civil War         8.2          PG-13      2016.0
# The Lovers                         4.5              R      2015.0
# Guardians of the Galaxy            8.1          PG-13      2014.0
# Interstellar                       8.6          PG-13      2014.0
# Inception                          8.8          PG-13      2010.0
# The Martian                        8.1          PG-13      2015.0
# Town & Country                     4.4              R      2001.0
# Sex and the City 2                 4.3              R      2010.0

# %% [markdown]
# ## Replicating boolen indexing with index selection
# * Using college dataset to select all institutions
# * Comparing each of their performance against one another

# %%
college = pd.read_csv(r'C:\Users\user\Desktop\Git_Python\New folder\data\college.csv')
# to specify which data will equal to that column
college[college['STABBR'] == 'TX'] .head()
# Out:
#                             INSTNM        CITY STABBR  HBCU  MENONLY  \
# 3610  Abilene Christian University     Abilene     TX   0.0      0.0
# 3611       Alvin Community College       Alvin     TX   0.0      0.0
# 3612              Amarillo College    Amarillo     TX   0.0      0.0
# 3613              Angelina College      Lufkin     TX   0.0      0.0
# 3614       Angelo State University  San Angelo     TX   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 3610        0.0         1     530.0     545.0           0.0  ...     0.0454
# 3611        0.0         0       NaN       NaN           0.0  ...     0.0002
# 3612        0.0         0       NaN       NaN           0.0  ...     0.0000
# 3613        0.0         0       NaN       NaN           0.0  ...     0.0264
# 3614        0.0         0     475.0     490.0           0.0  ...     0.0285
#
#       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...

# %%
# changing the index name and label column
college2 = college.set_index('STABBR')
college2.loc['TX'].head()
# Out:
#                               INSTNM        CITY  HBCU  MENONLY  WOMENONLY  \
# STABBR
# TX      Abilene Christian University     Abilene   0.0      0.0        0.0
# TX           Alvin Community College       Alvin   0.0      0.0        0.0
# TX                  Amarillo College    Amarillo   0.0      0.0        0.0
# TX                  Angelina College      Lufkin   0.0      0.0        0.0
# TX           Angelo State University  San Angelo   0.0      0.0        0.0
#
#         RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY    UGDS  ...  UGDS_2MOR  \
# STABBR                                                      ...
# TX             1     530.0     545.0           0.0  3572.0  ...     0.0454
# TX             0       NaN       NaN           0.0  4682.0  ...     0.0002
# TX             0       NaN       NaN           0.0  9346.0  ...     0.0000
# TX             0       NaN       NaN           0.0  3825.0  ...     0.0264
# ...

# %%
#lets compare the speed selection by %timeit
# %timeit college[college['STABBR'] =='TX']
# Out:
# 976 µs ± 8.33 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit college2.loc['TX']
# Out:
# 466 µs ± 3.63 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
#lets do with indexing opertor
# %timeit college2 = college.set_index('STABBR')
# Out:
# 1.83 ms ± 64.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
#it is possible to select both multiple states with boolen and index
states = ['TX','CA','NY']
college[college['STABBR'].isin(states)]  #boolen selection
college2.loc[states].head()
# Out:
#                               INSTNM        CITY  HBCU  MENONLY  WOMENONLY  \
# STABBR
# TX      Abilene Christian University     Abilene   0.0      0.0        0.0
# TX           Alvin Community College       Alvin   0.0      0.0        0.0
# TX                  Amarillo College    Amarillo   0.0      0.0        0.0
# TX                  Angelina College      Lufkin   0.0      0.0        0.0
# TX           Angelo State University  San Angelo   0.0      0.0        0.0
#
#         RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY    UGDS  ...  UGDS_2MOR  \
# STABBR                                                      ...
# TX             1     530.0     545.0           0.0  3572.0  ...     0.0454
# TX             0       NaN       NaN           0.0  4682.0  ...     0.0002
# TX             0       NaN       NaN           0.0  9346.0  ...     0.0000
# TX             0       NaN       NaN           0.0  3825.0  ...     0.0264
# ...

# %% [markdown]
# # Selected unique and sorted indexes
# * To from unique or sorted indexes
# * Comparing performance to Boolean indexing as well

# %%
college
# Out:
#                                                  INSTNM              CITY  \
# 0                              Alabama A & M University            Normal
# 1                   University of Alabama at Birmingham        Birmingham
# 2                                    Amridge University        Montgomery
# 3                   University of Alabama in Huntsville        Huntsville
# 4                              Alabama State University        Montgomery
# ...                                                 ...               ...
# 7530         SAE Institute of Technology  San Francisco        Emeryville
# 7531                  Rasmussen College - Overland Park     Overland Park
# 7532  National Personal Training Institute of Cleveland  Highland Heights
# 7533  Bay Area Medical Academy - San Jose Satellite ...          San Jose
# 7534            Excel Learning Center-San Antonio South       San Antonio
#
#      STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# ...

# %%
college2 = college.set_index('STABBR')

# %%
#check the index is sorted with monotonic
college2.index.is_monotonic
#if we get the 'False' the index is not sorted and contains duplites to check every objet
# Out:
# False

# %% [markdown]
# ## So here showing duplicates
# * To store the index to the another objest pandas takes the advantage searc and it is called as the "BINARY SEARCH"

# %%
college3 = college2.sort_index()
college3.index.is_monotonic
# Out:
# True

# %%
#search the tx from all the three data frames
# %timeit college[college['STABBR']=='TX']
# Out:
# 989 µs ± 13.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
#similarly for the loc index
# %timeit college2.loc['TX']
# Out:
# 464 µs ± 7.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
#lets do it for the thirs index
# %timeit college3.loc['TX']
# Out:
# 73.6 µs ± 784 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
#lest do it for the unique index
college_unique = college.set_index('INSTNM')

# %%
#unique colum for the index
college_unique.index.is_unique
# Out:
# True

# %%
#lets select the index for boolen index
college[college['INSTNM']=='Stanford University']
# Out:
#                    INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 4217  Stanford University  Stanford     CA   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 4217         0     730.0     745.0           0.0  ...     0.1067    0.0819
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 4217     0.0031       0.0         1   0.1556    0.1256   0.0401
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 4217            86000               12782
#
# [1 rows x 27 columns]

# %%
# lets select the stanford university for the unique index selection
college_unique.loc['Stanford University']
# Out:
# CITY                  Stanford
# STABBR                      CA
# HBCU                       0.0
# MENONLY                    0.0
# WOMENONLY                  0.0
# RELAFFIL                     0
# SATVRMID                 730.0
# SATMTMID                 745.0
# DISTANCEONLY               0.0
# UGDS                    7018.0
# UGDS_WHITE              0.3752
# UGDS_BLACK              0.0591
# UGDS_HISP               0.1607
# UGDS_ASIAN              0.1979
# UGDS_AIAN               0.0114
# UGDS_NHPI               0.0038
# UGDS_2MOR               0.1067
# UGDS_NRA                0.0819
# UGDS_UNKN               0.0031
# PPTUG_EF                   0.0
# CURROPER                     1
# PCTPELL                 0.1556
# PCTFLOAN                0.1256
# UG25ABV                 0.0401
# MD_EARN_WNE_P10          86000
# GRAD_DEBT_MDN_SUPP       12782
# Name: Stanford University, dtype: object

# %%
# lets time approach
# %timeit college[college['INSTNM']=='Stanford University']
# Out:
# 837 µs ± 5.97 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
#lts do for the loc index
# %timeit college_unique.loc['Stanford University']
# Out:
# 162 µs ± 9.25 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
