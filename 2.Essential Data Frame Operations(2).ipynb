# %% [markdown]
# * Accessing main DataFrame components
# * Understanding data types
# * Selecting single column of data as a Series
# * Calling Series method and working with operators on a Series
# * Changing Series method together
# * Making rows and columns names
# * Creating and deleting columns

# %% [markdown]
# # Working with Operators on DataFrame
# * Using multiple operators with a DataFrame
# * Rounding undergraduate columns to the nearest 100th
# * How result is equivalent to round method

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\user\Desktop\Git_Python\New folder\data\college.csv')
df.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...

# %%
# Changing the index column name
df1 = pd.read_csv(r'C:\Users\user\Desktop\Git_Python\New folder\data\college.csv',index_col='INSTNM')
df1.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
# ...

# %%
df1.index
# Out:
# Index(['Alabama A & M University', 'University of Alabama at Birmingham',
#        'Amridge University', 'University of Alabama in Huntsville',
#        'Alabama State University', 'The University of Alabama',
#        'Central Alabama Community College', 'Athens State University',
#        'Auburn University at Montgomery', 'Auburn University',
#        ...
#        'Strayer University-North Dallas', 'Strayer University-San Antonio',
#        'Strayer University-Stafford', 'WestMed College - Merced',
#        'Vantage College', 'SAE Institute of Technology  San Francisco',
#        'Rasmussen College - Overland Park',
#        'National Personal Training Institute of Cleveland',
#        'Bay Area Medical Academy - San Jose Satellite Location',
#        'Excel Learning Center-San Antonio South'],
#       dtype='object', name='INSTNM', length=7535)

# %%
df1.columns
# Out:
# Index(['CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
# selecting no of columns having same names
df_ugds = df1.filter(like='UGDS')
df_ugds.head()
# Out:
#                                         UGDS  UGDS_WHITE  UGDS_BLACK  \
# INSTNM
# Alabama A & M University              4206.0      0.0333      0.9353
# University of Alabama at Birmingham  11383.0      0.5922      0.2600
# Amridge University                     291.0      0.2990      0.4192
# University of Alabama in Huntsville   5451.0      0.6988      0.1255
# Alabama State University              4811.0      0.0158      0.9208
#
#                                      UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  \
# INSTNM
# Alabama A & M University                0.0055      0.0019     0.0024
# University of Alabama at Birmingham     0.0283      0.0518     0.0022
# Amridge University                      0.0069      0.0034     0.0000
# University of Alabama in Huntsville     0.0382      0.0376     0.0143
# Alabama State University                0.0121      0.0019     0.0010
#
#                                      UGDS_NHPI  UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %% [markdown]
# # Working on Operators

# %%
df_ugds +.00501
# Out:
#                                                            UGDS  UGDS_WHITE  \
# INSTNM
# Alabama A & M University                             4206.00501     0.03831
# University of Alabama at Birmingham                 11383.00501     0.59721
# Amridge University                                    291.00501     0.30401
# University of Alabama in Huntsville                  5451.00501     0.70381
# Alabama State University                             4811.00501     0.02081
# ...                                                         ...         ...
# SAE Institute of Technology  San Francisco                  NaN         NaN
# Rasmussen College - Overland Park                           NaN         NaN
# National Personal Training Institute of Cleveland           NaN         NaN
# Bay Area Medical Academy - San Jose Satellite L...          NaN         NaN
# Excel Learning Center-San Antonio South                     NaN         NaN
#
# ...

# %% [markdown]
# # Flow division operator to round the nearest whole number percentage

# %%
#here we use the flow division operator to ru the nearest number
(df_ugds +.00501) //.01
# Out:
#                                                          UGDS  UGDS_WHITE  \
# INSTNM
# Alabama A & M University                             420600.0         3.0
# University of Alabama at Birmingham                 1138300.0        59.0
# Amridge University                                    29100.0        30.0
# University of Alabama in Huntsville                  545100.0        70.0
# Alabama State University                             481100.0         2.0
# ...                                                       ...         ...
# SAE Institute of Technology  San Francisco                NaN         NaN
# Rasmussen College - Overland Park                         NaN         NaN
# National Personal Training Institute of Cleveland         NaN         NaN
# Bay Area Medical Academy - San Jose Satellite L...        NaN         NaN
# Excel Learning Center-San Antonio South                   NaN         NaN
#
# ...

# %%
# After finishing divisible 100 to remove closest numbers
#round:rounding the values
df_ugds_round = (df_ugds +.00501)//.01/100
df_ugds_round.head()
# Out:
#                                         UGDS  UGDS_WHITE  UGDS_BLACK  \
# INSTNM
# Alabama A & M University              4206.0        0.03        0.94
# University of Alabama at Birmingham  11383.0        0.59        0.26
# Amridge University                     291.0        0.30        0.42
# University of Alabama in Huntsville   5451.0        0.70        0.13
# Alabama State University              4811.0        0.02        0.92
#
#                                      UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  \
# INSTNM
# Alabama A & M University                  0.01        0.00       0.00
# University of Alabama at Birmingham       0.03        0.05       0.00
# Amridge University                        0.01        0.00       0.00
# University of Alabama in Huntsville       0.04        0.04       0.01
# Alabama State University                  0.01        0.00       0.00
#
#                                      UGDS_NHPI  UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
#After rounding make the DataFrame_round
df_ugds_round1 =(df_ugds +.00001).round(2)
df_ugds_round1.head()
# Out:
#                                         UGDS  UGDS_WHITE  UGDS_BLACK  \
# INSTNM
# Alabama A & M University              4206.0        0.03        0.94
# University of Alabama at Birmingham  11383.0        0.59        0.26
# Amridge University                     291.0        0.30        0.42
# University of Alabama in Huntsville   5451.0        0.70        0.13
# Alabama State University              4811.0        0.02        0.92
#
#                                      UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  \
# INSTNM
# Alabama A & M University                  0.01        0.00       0.00
# University of Alabama at Birmingham       0.03        0.05       0.00
# Amridge University                        0.01        0.00       0.00
# University of Alabama in Huntsville       0.04        0.04       0.01
# Alabama State University                  0.01        0.00       0.00
#
#                                      UGDS_NHPI  UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %% [markdown]
# # Equal DataFrame

# %%
#checking both normal and rounding data column and index are equal.
df_ugds_round.equals(df_ugds_round1)
# Out:
# True

# %% [markdown]
# # Comparing missing values
# ### Using the equals operator

# %%
np.nan == np.nan
# Out:
# False

# %%
None == None
# Out:
# True

# %%
np.nan > 5
# Out:
# False

# %%
5 > np.nan
# Out:
# False

# %%
np.nan != 5
# Out:
# True

# %%
#Checking equal to equal the operator
# comparing by an each element by a sclar value
df1
df_ugds == .0019
# Out:
#                                                      UGDS  UGDS_WHITE  \
# INSTNM
# Alabama A & M University                            False       False
# University of Alabama at Birmingham                 False       False
# Amridge University                                  False       False
# University of Alabama in Huntsville                 False       False
# Alabama State University                            False       False
# ...                                                   ...         ...
# SAE Institute of Technology  San Francisco          False       False
# Rasmussen College - Overland Park                   False       False
# National Personal Training Institute of Cleveland   False       False
# Bay Area Medical Academy - San Jose Satellite L...  False       False
# Excel Learning Center-San Antonio South             False       False
#
#                                                     UGDS_BLACK  UGDS_HISP  \
# INSTNM
# ...

# %%
#comparing two data frames one another
df_self_compare = df_ugds == df_ugds
df_self_compare.head()
# Out:
#                                      UGDS  UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University             True        True        True       True
# University of Alabama at Birmingham  True        True        True       True
# Amridge University                   True        True        True       True
# University of Alabama in Huntsville  True        True        True       True
# Alabama State University             True        True        True       True
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                   True       True       True
# University of Alabama at Birmingham        True       True       True
# Amridge University                         True       True       True
# University of Alabama in Huntsville        True       True       True
# Alabama State University                   True       True       True
#
# ...

# %%
#Determining each column which contains false
df_self_compare.all()
# Out:
# UGDS          False
# UGDS_WHITE    False
# UGDS_BLACK    False
# UGDS_HISP     False
# UGDS_ASIAN    False
# UGDS_AIAN     False
# UGDS_NHPI     False
# UGDS_2MOR     False
# UGDS_NRA      False
# UGDS_UNKN     False
# dtype: bool

# %%
#Comparing with np.nan and summing
(df_ugds ==np.nan).sum()
# Out:
# UGDS          0
# UGDS_WHITE    0
# UGDS_BLACK    0
# UGDS_HISP     0
# UGDS_ASIAN    0
# UGDS_AIAN     0
# UGDS_NHPI     0
# UGDS_2MOR     0
# UGDS_NRA      0
# UGDS_UNKN     0
# dtype: int64

# %%
#primary way to counting missing values is null method
df_ugds.isnull().sum()
# Out:
# UGDS          661
# UGDS_WHITE    661
# UGDS_BLACK    661
# UGDS_HISP     661
# UGDS_ASIAN    661
# UGDS_AIAN     661
# UGDS_NHPI     661
# UGDS_2MOR     661
# UGDS_NRA      661
# UGDS_UNKN     661
# dtype: int64

# %%
#The correct way to compare two data sets is"equals", Not this"==""
df_ugds.equals(df_ugds)
# Out:
# True

# %% [markdown]
# # Transposing the Direction of a DataFrame
# #### Invoking a method with the direction of its operation transposed
# ### Axis Parameter
# #### It controls the direction in which the operation takes place
# #### It can only be one of two values -0 0r 1

# %%
df1
# Out:
#                                                                 CITY STABBR  \
# INSTNM
# Alabama A & M University                                      Normal     AL
# University of Alabama at Birmingham                       Birmingham     AL
# Amridge University                                        Montgomery     AL
# University of Alabama in Huntsville                       Huntsville     AL
# Alabama State University                                  Montgomery     AL
# ...                                                              ...    ...
# SAE Institute of Technology  San Francisco                Emeryville     CA
# Rasmussen College - Overland Park                      Overland Park     KS
# National Personal Training Institute of Cleveland   Highland Heights     OH
# Bay Area Medical Academy - San Jose Satellite L...          San Jose     CA
# Excel Learning Center-San Antonio South                  San Antonio     TX
#
# ...

# %%
# selecting no of columns having same names
df_ugds = df1.filter(like='UGDS_')
df_ugds.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
#to check the number og non-missing values
df_ugds.count()
# Out:
# UGDS_WHITE    6874
# UGDS_BLACK    6874
# UGDS_HISP     6874
# UGDS_ASIAN    6874
# UGDS_AIAN     6874
# UGDS_NHPI     6874
# UGDS_2MOR     6874
# UGDS_NRA      6874
# UGDS_UNKN     6874
# dtype: int64

# %%
#counting the non-missing values
#It Transpose the dataframe by column non-missing value
df_ugds.count(axis='columns').head()
# Out:
# INSTNM
# Alabama A & M University               9
# University of Alabama at Birmingham    9
# Amridge University                     9
# University of Alabama in Huntsville    9
# Alabama State University               9
# dtype: int64

# %%
#suming the non missing values
df_ugds.sum(axis='columns').head()
# Out:
# INSTNM
# Alabama A & M University               1.0000
# University of Alabama at Birmingham    0.9999
# Amridge University                     1.0000
# University of Alabama in Huntsville    1.0000
# Alabama State University               1.0000
# dtype: float64

# %%
#to find out distribution of each colum
df_ugds.median(axis='index')
# Out:
# UGDS_WHITE    0.55570
# UGDS_BLACK    0.10005
# UGDS_HISP     0.07140
# UGDS_ASIAN    0.01290
# UGDS_AIAN     0.00260
# UGDS_NHPI     0.00000
# UGDS_2MOR     0.01750
# UGDS_NRA      0.00000
# UGDS_UNKN     0.01430
# dtype: float64

# %% [markdown]
# # Determining college Campus Diversity
# ### Caliculating the diversity metric
# ### Finding out top 10 US New schools fared with basic diversity metric

# %% [markdown]
# ###### Diversity : "when we want to quantify something without knowing anything  diversity

# %%
pd.read_csv(r'C:\Users\user\Desktop\Git_Python\New folder\data\college_diversity.csv',index_col='School')
# Out:
#                                                    Diversity Index
# School
# Rutgers University--Newark  Newark, NJ                        0.76
# Andrews University  Berrien Springs, MI                       0.74
# Stanford University  Stanford, CA                             0.74
# University of Houston  Houston, TX                            0.74
# University of Nevada--Las Vegas  Las Vegas, NV                0.74
# University of San Francisco  San Francisco, CA                0.74
# San Francisco State University  San Francisco, CA             0.73
# University of Illinois--Chicago  Chicago, IL                  0.73
# New Jersey Institute of Technology  Newark, NJ                0.72
# Texas Woman's University  Denton, TX                          0.72

# %%
df1
# selecting no of columns having same names
df_ugds = df1.filter(like='UGDS_')
df_ugds.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
# Sorting the Series from the Highest to Lowest and finding the missing rows
df_ugds.isnull().sum(axis=1).sort_values(ascending=False).head()
# Out:
# INSTNM
# Excel Learning Center-San Antonio South              9
# Western State College of Law at Argosy University    9
# Albany Law School                                    9
# Albany Medical College                               9
# A T Still University of Health Sciences              9
# dtype: int64

# %% [markdown]
# ### This shows the number without missing values

# %%
# For adding missing values in Nan in the strings we use
df1_ugds = df_ugds.dropna(how='all')

# %%
# we can count the missing values 
df1_ugds.isnull().sum()
# Out:
# UGDS_WHITE    0
# UGDS_BLACK    0
# UGDS_HISP     0
# UGDS_ASIAN    0
# UGDS_AIAN     0
# UGDS_NHPI     0
# UGDS_2MOR     0
# UGDS_NRA      0
# UGDS_UNKN     0
# dtype: int64

# %%
# AFTER all this we can caliculate "DIVERSITY MATRIC"
df1_ugds.ge(.15)
# Out:
#                                                     UGDS_WHITE  UGDS_BLACK  \
# INSTNM
# Alabama A & M University                                 False        True
# University of Alabama at Birmingham                       True        True
# Amridge University                                        True        True
# University of Alabama in Huntsville                       True       False
# Alabama State University                                 False        True
# ...                                                        ...         ...
# Hollywood Institute of Beauty Careers-West Palm...        True        True
# Hollywood Institute of Beauty Careers-Casselberry        False        True
# Coachella Valley Beauty College-Beaumont                  True       False
# Dewey University-Mayaguez                                False       False
# Coastal Pines Technical College                           True        True
#
# ...

# %%
#from hear we fill findout the true value for the each index
df2_ugds.ge(.15).sum(axis='columns').head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-4c36bd821d5c> in <module>
#       1 #from hear we fill findout the true value for the each index
# ----> 2 df2_ugds.ge(.15).sum(axis='columns').head()
#
# NameError: name 'df2_ugds' is not defined

# %%
#finding the Distribution
df_ugds_div.value_counts()

# %%
#to frind out diversity matric which one they are
df_ugds_div.sort_values(ascending=False).head()

# %%
#to find out the raw percentage of the each school
#df_ugds.iloc[['Amridge University','University of Alabama at Birmingham ']]

# %%
#df_ugds_div.loc['Rutgers University-Newark',
#               'Andrews University',
#              'Stanford University',
#              'University of Houston',
#               'University of Nevada-Las Vegas']
